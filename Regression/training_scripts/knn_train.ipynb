# %% [markdown]
# Contenido:
#
# - Entrenamiento de algoritmo SVC

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../attributes_std.csv", index_col=0)
df.head()
# Out:
#        area  eccentricity    extent  GLCM Contrast  GLCM dissimilarity  \
# 0  0.043333     -2.226854  0.363292      -1.542844            0.091402
# 1  0.049185     -2.203262  0.934037       0.913422           -1.606446
# 2  0.043025     -2.231439  0.362645      -1.459200           -0.070608
# 3  0.051649     -2.219723  0.939462       0.426138           -0.348248
# 4  0.042409     -2.227843  0.361352      -1.541941            0.098691
#
#    GLCM homogeneity  GLCM ASM  GLCM energy  GLCM correlation   hist_r5  ...  \
# 0          0.646588 -0.157328     0.071042         -1.542844 -0.284688  ...
# 1          1.293831  1.704348     1.473114          0.913422 -0.284688  ...
# 2          0.710590 -0.076057     0.150221         -1.459200 -0.284688  ...
# 3         -0.847317 -1.104154    -1.280729          0.426138 -0.284688  ...
# 4          0.642377 -0.147996     0.080277         -1.541941 -0.284688  ...
#
#    hist_v10  hist_v11  hist_v12  hist_v13  hist_v14  hist_v15  hist_v16  \
# 0  1.955997  1.911448  0.967515 -0.302177  0.080586  1.363820  2.254121
# 1  1.869296  1.859591  1.112211 -0.054567  0.080586  1.217367  2.369830
# 2  2.048186  1.842658  0.988737 -0.201795  0.046530  1.281440  2.264640
# 3  1.906610  1.834191  1.150797 -0.034490 -0.021582  1.263134  2.464500
# 4  1.962582  1.907214  0.944363 -0.248640  0.160050  1.308900  2.212045
#
#    hist_v17  hist_v18  Weight
# 0 -0.258405 -0.166822    1.66
# 1  0.464176 -0.166822    1.66
# 2 -0.258405 -0.166822    1.66
# 3  0.388115 -0.166822    1.66
# 4 -0.144313 -0.166822    1.66
#
# [5 rows x 92 columns]

# %%
X = df.loc[:, df.columns != 'Weight']

Y = df["Weight"]

print(np.shape(X))
print(np.shape(Y))
# Out:
# (12896, 91)
# (12896,)

# %%
# HYPERPARAMETER GRID SEARCH
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV, KFold

from sklearn.model_selection import GridSearchCV


param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11, 15, 21],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'chebyshev'],
    'p': [1, 2]
}

svr = KNeighborsRegressor()

grid_search = GridSearchCV(
    estimator=svr,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=5,
    n_jobs=-1
)

# Fit GridSearchCV
grid_search.fit(X, Y)

# Print the best parameters and score
print("Best parameters found: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# Best parameters found:  {'metric': 'manhattan', 'n_neighbors': 11, 'p': 1, 'weights': 'distance'}
# Best score:  -0.07883953035238

# %%
from sklearn.neighbors import KNeighborsRegressor

svr = KNeighborsRegressor(metric='manhattan', n_neighbors= 11, p= 1, weights='distance')

svr.fit(X, Y)
# Out:
# KNeighborsRegressor(metric='manhattan', n_neighbors=11, p=1, weights='distance')

# %%
import pickle

# Save models with pickle
with open('../models/knn.pkl', 'wb') as f:
    pickle.dump(svr, f)
