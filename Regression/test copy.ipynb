# %%
import pandas as pd
import pickle
import cv2
import matplotlib.pyplot as plt
import preprocessing
import numpy as np

# %%
df = pd.read_csv("../Dataset/labels_test.csv",index_col=0)
df.head()
# Out:
#                       Image path Class  Weight
# 0  Dataset/Test/FBO1/cacao-1.jpg  FBO1    1.50
# 1  Dataset/Test/FBO1/cacao-2.jpg  FBO1    1.43
# 2  Dataset/Test/FBO1/cacao-3.jpg  FBO1    1.45
# 3  Dataset/Test/FBO1/cacao-4.jpg  FBO1    1.45
# 4  Dataset/Test/FBO1/cacao-5.jpg  FBO1    1.24

# %%
from tqdm import tqdm
test_data = []

for i in tqdm(range(len(df))):
    img = cv2.imread("../" + df.iloc[i]["Image path"])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    attr = preprocessing.extract_attributes(img)

    flattened = [item for sublist in attr for item in (sublist if isinstance(sublist, np.ndarray) else [sublist])]

    test_data.append(flattened)

test = pd.DataFrame(test_data, columns=preprocessing.get_all_columns())

test = test[preprocessing.get_columns()]
test.head()
# Out:
# 100%|██████████| 180/180 [00:21<00:00,  8.54it/s]
#       area  eccentricity    extent  GLCM Contrast  GLCM dissimilarity  \
# 0  17535.0      0.724617  0.771346       0.952273            3.611906
# 1  15811.0      0.784854  0.755423       0.957507            3.504364
# 2  19755.0      0.759615  0.739057       0.956669            3.846269
# 3  15807.0      0.784169  0.736031       0.959143            3.394236
# 4  15605.0      0.774226  0.755763       0.953216            3.605596
#
#    GLCM homogeneity  GLCM ASM  GLCM energy  GLCM correlation  hist_r5  ...  \
# 0          0.404085  0.008753     0.093560          0.952273      0.0  ...
# 1          0.395377  0.008252     0.090839          0.957507      0.0  ...
# 2          0.400504  0.008772     0.093658          0.956669      0.0  ...
# 3          0.417254  0.009203     0.095935          0.959143      0.0  ...
# 4          0.405617  0.009186     0.095843          0.953216      0.0  ...
#
#    hist_v9  hist_v10  hist_v11  hist_v12  hist_v13  hist_v14  hist_v15  \
# 0   4320.0    5241.0    3745.0    1447.0     263.0     203.0     231.0
# 1   4204.0    5374.0    3212.0     556.0     202.0     194.0     240.0
# 2   5490.0    5637.0    4232.0    1952.0     271.0     153.0     180.0
# 3   3719.0    4328.0    3082.0    1545.0     327.0     198.0     249.0
# 4   4243.0    3592.0    3004.0    1435.0     336.0     211.0     225.0
#
#    hist_v16  hist_v17  hist_v18
# 0     324.0     102.0       0.0
# 1     249.0      17.0       0.0
# 2     217.0      52.0       0.0
# 3     211.0       4.0       0.0
# 4     227.0       0.0       0.0
#
# [5 rows x 91 columns]

# %%
import joblib


scaler = joblib.load("models/scaler.pkl")

X = scaler.transform(test)
X = pd.DataFrame(X, columns=preprocessing.get_columns())
Y = df["Weight"]

# %%
# SVC test

from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, root_mean_squared_error

with open("models/svr.pkl", 'rb') as file:
    svc = pickle.load(file)

svr_predictions = svc.predict(X)

r2 = r2_score(Y, svr_predictions)
MAE = mean_absolute_error(Y, svr_predictions)
MAPE = mean_absolute_percentage_error(Y, svr_predictions)
RMSE = root_mean_squared_error(Y, svr_predictions)

print(f"R2: {r2}")
print(f"Mean Absolute Error: {MAE}")
print(f"Mean Absolute Percentage Error: {MAPE}%")
print(f"Root Mean Squared Error: {RMSE}")
# Out:
# R2: 0.8765351230527161
# Mean Absolute Error: 0.10019082091902771
# Mean Absolute Percentage Error: 0.06869038246312689%
# Root Mean Squared Error: 0.1295566170810871
